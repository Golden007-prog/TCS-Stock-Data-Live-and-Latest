# %% [markdown]
# ![Data_Layer](img\ML.png)

# %% [markdown]
# # Machine Learning Layer (Individual Models per Horizon)
# This notebook trains and saves separate models for each time window.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib, os
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from warnings import filterwarnings
filterwarnings("ignore")

os.makedirs('models', exist_ok=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Creating evaluate and plot_predictions functions

# %%
def evaluate(y_true, y_pred):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    print(f"Evaluation Metrics:\nMAE: {mae:.2f}\nRMSE: {rmse:.2f}\nR²: {r2:.2f}")
    return mae, rmse, r2

def plot_predictions(y_true, y_pred, title):
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    plt.figure(figsize=(12, 5))
    plt.plot(y_true, label='Actual', linewidth=2)
    plt.plot(y_pred, label='Predicted', linestyle='--')
    plt.title(title)
    plt.xlabel("Time Step")
    plt.ylabel("Price")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save RF and XGBoost Model: 1D

# %%
df = pd.read_csv('data/processed/tcs_1d_features.csv')
features = ['Open', 'High', 'Low', 'Volume', 'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line', 'Lag_1', 'Lag_2', 'Lag_3']
target = 'Tomorrow'
df.dropna(subset=features + [target], inplace=True)
X, y = df[features], df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train Random Forest
print("\nTraining Random Forest for 1D")
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
evaluate(y_test, rf_pred)
plot_predictions(y_test, rf_pred, 'Random Forest - 1D')
joblib.dump(rf, 'models/rf_1d.pkl')

# Train XGBoost
print("\nTraining XGBoost for 1D")
xgb = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=42)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)
evaluate(y_test, xgb_pred)
plot_predictions(y_test, xgb_pred, 'XGBoost - 1D')
joblib.dump(xgb, 'models/xgb_1d.pkl')
# Out:
# Training Random Forest for 1D
# Evaluation Metrics:
# MAE: 1.95
# RMSE: 2.65
# R²: 0.95
# Training XGBoost for 1D
# Evaluation Metrics:
# MAE: 2.05
# RMSE: 2.74
# R²: 0.94
# ['models/xgb_1d.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save RF and XgBoost Model: 5D

# %%
df = pd.read_csv('data/processed/tcs_5d_features.csv')
features = ['Open', 'High', 'Low', 'Volume', 'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line', 'Lag_1', 'Lag_2']
target = 'Tomorrow'
df.dropna(subset=features + [target], inplace=True)
X, y = df[features], df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train Random Forest
print("\nTraining Random Forest for 5D")
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
evaluate(y_test, rf_pred)
plot_predictions(y_test, rf_pred, 'Random Forest - 5D')
joblib.dump(rf, 'models/rf_5d.pkl')

# Train XGBoost
print("\nTraining XGBoost for 5D")
xgb = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=42)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)
evaluate(y_test, xgb_pred)
plot_predictions(y_test, xgb_pred, 'XGBoost - 5D')
joblib.dump(xgb, 'models/xgb_5d.pkl')
# Out:
# Training Random Forest for 5D
# Evaluation Metrics:
# MAE: 13.39
# RMSE: 16.93
# R²: -0.01
# Training XGBoost for 5D
# Evaluation Metrics:
# MAE: 15.61
# RMSE: 19.98
# R²: -0.41
# ['models/xgb_5d.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save RF and XgBoost Model: 1M

# %%
df = pd.read_csv('data/processed/tcs_1m_features.csv')

# Define Features and Target
features = [
    'Open', 'High', 'Low', 'Volume',
    'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line',
    'Lag_1', 'Lag_2', 'Lag_3'
]
target = 'Tomorrow'

df.dropna(subset=features + [target], inplace=True)

X = df[features]
y = df[target]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# ─────────────────────────────────────
# Random Forest Model
print("\nTraining Random Forest for 1M")
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

evaluate(y_test, rf_pred)
plot_predictions(y_test, rf_pred, 'Random Forest - 1M')
joblib.dump(rf, 'models/rf_1m.pkl')

# ─────────────────────────────────────
# XGBoost Model
print("\nTraining XGBoost for 1M")
xgb = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=42)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)

evaluate(y_test, xgb_pred)
plot_predictions(y_test, xgb_pred, 'XGBoost - 1M')
joblib.dump(xgb, 'models/xgb_1m.pkl')
# Out:
# Training Random Forest for 1M
# Evaluation Metrics:
# MAE: 41.37
# RMSE: 59.38
# R²: 0.01
# Training XGBoost for 1M
# Evaluation Metrics:
# MAE: 52.90
# RMSE: 74.42
# R²: -0.56
# ['models/xgb_1m.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save RF and XgBoost Model: 6M

# %%
# Load and preprocess 6M data
df = pd.read_csv('data/processed/tcs_6m_features.csv')
features = [
    'Open', 'High', 'Low', 'Volume',
    'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line',
    'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7'
]
target = 'Tomorrow'
df.dropna(subset=features + [target], inplace=True)
X, y = df[features], df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Evaluation Function
def evaluate(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    print(f"\n6M Evaluation Metrics:\nMAE : {mae:.2f} | RMSE: {rmse:.2f} | R²: {r2:.2f}")

# Plotting Function
def plot_predictions(y_true, y_pred, title):
    plt.figure(figsize=(12, 5))
    plt.plot(y_true.values, label='Actual')
    plt.plot(y_pred, label='Predicted', linestyle='--')
    plt.title(title)
    plt.xlabel("Time Step")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Train Random Forest
print("\nTraining Random Forest for 6M")
rf = RandomForestRegressor(n_estimators=200, max_depth=10, min_samples_split=2, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
evaluate(y_test, rf_pred)
plot_predictions(y_test, rf_pred, 'Random Forest - 6M')
joblib.dump(rf, 'models/rf_6m.pkl')

# Train XGBoost
print("\nTraining XGBoost for 6M")
xgb = XGBRegressor(n_estimators=200, learning_rate=0.05, max_depth=6,
                   subsample=0.8, colsample_bytree=0.8, random_state=42)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)
evaluate(y_test, xgb_pred)
plot_predictions(y_test, xgb_pred, 'XGBoost - 6M')
joblib.dump(xgb, 'models/xgb_6m.pkl')
# Out:
# Training Random Forest for 6M
#
# 6M Evaluation Metrics:
# MAE : 123.45 | RMSE: 151.74 | R²: -0.63
# Training XGBoost for 6M
#
# 6M Evaluation Metrics:
# MAE : 128.93 | RMSE: 160.03 | R²: -0.81
# ['models/xgb_6m.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save LSTM Model - 1Y

# %%
# Setup
os.makedirs('models', exist_ok=True)

# Load Data
df = pd.read_csv('data/processed/tcs_1y_features.csv')

features = [
    'Open', 'High', 'Low', 'Volume',
    'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line',
    'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7'
]
target = 'Tomorrow'

df.dropna(subset=features + [target], inplace=True)

# ─────────────────────────────────────────────
# Scale
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

X_scaled = X_scaler.fit_transform(df[features])
y_scaled = y_scaler.fit_transform(df[[target]])

# Sequence Generation
lookback = 180
X_seq, y_seq = [], []
for i in range(lookback, len(X_scaled)):
    X_seq.append(X_scaled[i - lookback:i])
    y_seq.append(y_scaled[i])
X_seq, y_seq = np.array(X_seq), np.array(y_seq)

# Split
split_idx = int(len(X_seq) * 0.8)
X_train, X_test = X_seq[:split_idx], X_seq[split_idx:]
y_train, y_test = y_seq[:split_idx], y_seq[split_idx:]

# ─────────────────────────────────────────────
# Fine-Tuned LSTM Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mae')

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

# Train
model.fit(X_train, y_train,
          epochs=100,
          batch_size=32,
          validation_split=0.1,
          callbacks=[early_stop, reduce_lr],
          verbose=1)

# ─────────────────────────────────────────────
# Evaluate
y_pred_scaled = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_scaled)
y_actual = y_scaler.inverse_transform(y_test)

mae = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)
print(f"\nLSTM (1Y Fine-Tuned) Evaluation:\nMAE: {mae:.2f} | RMSE: {rmse:.2f} | R²: {r2:.2f}")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(y_actual, label='Actual')
plt.plot(y_pred, label='Predicted', linestyle='--')
plt.title('LSTM - 1Y Fine-Tuned')
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Save model and scalers
model.save('models/lstm_1y_finetuned.keras')
joblib.dump(X_scaler, 'models/X_scaler_1y_finetuned.pkl')
joblib.dump(y_scaler, 'models/y_scaler_1y_finetuned.pkl')
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.4535 - val_loss: 0.1611 - learning_rate: 0.0010
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1506 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1215 - val_loss: 0.1017 - learning_rate: 0.0010
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1215 - val_loss: 0.0638 - learning_rate: 0.0010
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1091 - val_loss: 0.0857 - learning_rate: 0.0010
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1006 - val_loss: 0.0616 - learning_rate: 0.0010
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1011 - val_loss: 0.0780 - learning_rate: 0.0010
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1021 - val_loss: 0.0669 - learning_rate: 0.0010
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1048 - val_loss: 0.0987 - learning_rate: 0.0010
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1062 - val_loss: 0.0570 - learning_rate: 0.0010
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0889 - val_loss: 0.0682 - learning_rate: 0.0010
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1010 - val_loss: 0.0540 - learning_rate: 0.0010
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0986 - val_loss: 0.0610 - learning_rate: 0.0010
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0946 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0787 - val_loss: 0.0576 - learning_rate: 0.0010
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0910 - val_loss: 0.0803 - learning_rate: 0.0010
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0896 - val_loss: 0.0645 - learning_rate: 0.0010
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0946 - val_loss: 0.0790 - learning_rate: 5.0000e-04
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0936 - val_loss: 0.0530 - learning_rate: 5.0000e-04
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0867 - val_loss: 0.0594 - learning_rate: 5.0000e-04
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0746 - val_loss: 0.0547 - learning_rate: 5.0000e-04
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0854 - val_loss: 0.0496 - learning_rate: 5.0000e-04
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0802 - val_loss: 0.0584 - learning_rate: 5.0000e-04
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0758 - val_loss: 0.0518 - learning_rate: 5.0000e-04
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0877 - val_loss: 0.0678 - learning_rate: 5.0000e-04
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0798 - val_loss: 0.0516 - learning_rate: 5.0000e-04
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0884 - val_loss: 0.0628 - learning_rate: 5.0000e-04
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0841 - val_loss: 0.0511 - learning_rate: 2.5000e-04
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0778 - val_loss: 0.0576 - learning_rate: 2.5000e-04
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0820 - val_loss: 0.0594 - learning_rate: 2.5000e-04
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0797 - val_loss: 0.0488 - learning_rate: 2.5000e-04
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0907 - val_loss: 0.0510 - learning_rate: 2.5000e-04
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0787 - val_loss: 0.0490 - learning_rate: 2.5000e-04
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0827 - val_loss: 0.0527 - learning_rate: 2.5000e-04
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0836 - val_loss: 0.0485 - learning_rate: 2.5000e-04
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0794 - val_loss: 0.0536 - learning_rate: 2.5000e-04
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0818 - val_loss: 0.0533 - learning_rate: 2.5000e-04
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0741 - val_loss: 0.0537 - learning_rate: 2.5000e-04
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0786 - val_loss: 0.0596 - learning_rate: 2.5000e-04
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0723 - val_loss: 0.0502 - learning_rate: 2.5000e-04
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0840 - val_loss: 0.0508 - learning_rate: 1.2500e-04
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0715 - val_loss: 0.0551 - learning_rate: 1.2500e-04
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0795 - val_loss: 0.0551 - learning_rate: 1.2500e-04
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0721 - val_loss: 0.0498 - learning_rate: 1.2500e-04
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0759 - val_loss: 0.0501 - learning_rate: 1.2500e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
#
# LSTM (1Y Fine-Tuned) Evaluation:
# MAE: 114.55 | RMSE: 151.71 | R²: -0.59
# ['models/y_scaler_1y_finetuned.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## Train and Save LSTM Model - 5Y

# %%
# Setup
os.makedirs('models', exist_ok=True)

# Load Data
df = pd.read_csv('data/processed/tcs_5y_features.csv')

features = [
    'Open', 'High', 'Low', 'Volume',
    'MA20', 'MA50', 'RSI', 'MACD', 'Signal_Line',
    'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7'
]
target = 'Tomorrow'

df.dropna(subset=features + [target], inplace=True)

# ─────────────────────────────────────────────
# Scale
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

X_scaled = X_scaler.fit_transform(df[features])
y_scaled = y_scaler.fit_transform(df[[target]])

# Sequence Generation
lookback = 12 # 20 weeks
X_seq, y_seq = [], []
for i in range(lookback, len(X_scaled)):
    X_seq.append(X_scaled[i - lookback:i])
    y_seq.append(y_scaled[i])
X_seq, y_seq = np.array(X_seq), np.array(y_seq)

# Split
split_idx = int(len(X_seq) * 0.8)
X_train, X_test = X_seq[:split_idx], X_seq[split_idx:]
y_train, y_test = y_seq[:split_idx], y_seq[split_idx:]

# ─────────────────────────────────────────────
# Fine-Tuned LSTM Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='mae')

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

# Train
model.fit(X_train, y_train,
          epochs=100,
          batch_size=32,
          validation_split=0.1,
          callbacks=[early_stop, reduce_lr],
          verbose=1)

# ─────────────────────────────────────────────
# Evaluate
y_pred_scaled = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_scaled)
y_actual = y_scaler.inverse_transform(y_test)

mae = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)
print(f"\nLSTM (5Y Fine-Tuned) Evaluation:\nMAE: {mae:.2f} | RMSE: {rmse:.2f} | R²: {r2:.2f}")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(y_actual, label='Actual')
plt.plot(y_pred, label='Predicted', linestyle='--')
plt.title('LSTM - 5Y Fine-Tuned')
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Save model and scalers
model.save('models/lstm_5y_finetuned.keras')
joblib.dump(X_scaler, 'models/X_scaler_5y_finetuned.pkl')
joblib.dump(y_scaler, 'models/y_scaler_5y_finetuned.pkl')
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.4436 - val_loss: 0.7903 - learning_rate: 0.0100
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2273 - val_loss: 0.1044 - learning_rate: 0.0100
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2389 - val_loss: 0.1466 - learning_rate: 0.0100
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1498 - val_loss: 0.2694 - learning_rate: 0.0100
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1173 - val_loss: 0.1705 - learning_rate: 0.0100
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1211 - val_loss: 0.1534 - learning_rate: 0.0100
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1124 - val_loss: 0.1658 - learning_rate: 0.0100
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1048 - val_loss: 0.1505 - learning_rate: 0.0050
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0936 - val_loss: 0.1418 - learning_rate: 0.0050
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0928 - val_loss: 0.1451 - learning_rate: 0.0050
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0902 - val_loss: 0.1489 - learning_rate: 0.0050
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0949 - val_loss: 0.1562 - learning_rate: 0.0050
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/stepWARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000207109C96C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#
# LSTM (5Y Fine-Tuned) Evaluation:
# MAE: 251.79 | RMSE: 318.55 | R²: 0.20
# ['models/y_scaler_5y_finetuned.pkl']

# %% [markdown]
# ---
